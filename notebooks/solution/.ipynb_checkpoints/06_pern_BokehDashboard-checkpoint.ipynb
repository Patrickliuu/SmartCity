# %%
# %pip install -r ../../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining src from git+ssh://****@github.com/soe-classrooms/smartcity-01-Patrickliuu.git@aa259dd6387db86538ab45a69f3047a75ba45bd2#egg=src (from -r ../../requirements.txt (line 54))
#   Cloning ssh://****@github.com/soe-classrooms/smartcity-01-Patrickliuu.git (to revision aa259dd6387db86538ab45a69f3047a75ba45bd2) to ./src/src
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/soe-classrooms/smartcity-01-Patrickliuu.git' /home/pindalu/FS2024/DSIOT/smartcity-01-Patrickliuu/notebooks/solution/src/src
#   Running command git rev-parse -q --verify 'sha^aa259dd6387db86538ab45a69f3047a75ba45bd2'
#   Running command git fetch -q 'ssh://****@github.com/soe-classrooms/smartcity-01-Patrickliuu.git' aa259dd6387db86538ab45a69f3047a75ba45bd2
#   Running command git checkout -q aa259dd6387db86538ab45a69f3047a75ba45bd2
#   Resolved ssh://****@github.com/soe-classrooms/smartcity-01-Patrickliuu.git to commit aa259dd6387db86538ab45a69f3047a75ba45bd2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiofiles==23.2.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 1)) (23.2.1)
# Requirement already satisfied: aiohttp==3.9.3 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 2)) (3.9.3)
# Requirement already satisfied: aiosignal==1.3.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: annotated-types==0.6.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 4)) (0.6.0)
# Collecting anyio==4.3.0 (from -r ../../requirements.txt (line 5))
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: asgiref==3.7.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 6)) (3.7.2)
# Requirement already satisfied: async-timeout==4.0.3 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 7)) (4.0.3)
# Collecting attrs==23.2.0 (from -r ../../requirements.txt (line 8))
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting certifi==2024.2.2 (from -r ../../requirements.txt (line 9))
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting chardet==5.2.0 (from -r ../../requirements.txt (line 10))
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting charset-normalizer==3.3.2 (from -r ../../requirements.txt (line 11))
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting distro==1.9.0 (from -r ../../requirements.txt (line 12))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: dnspython==2.6.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 13)) (2.6.1)
# Collecting exceptiongroup==1.2.0 (from -r ../../requirements.txt (line 14))
#   Using cached exceptiongroup-1.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting frozenlist==1.4.1 (from -r ../../requirements.txt (line 15))
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: h11==0.14.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 16)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.3 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 17)) (1.0.3)
# Requirement already satisfied: httpx==0.26.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 18)) (0.26.0)
# Collecting idna==3.6 (from -r ../../requirements.txt (line 19))
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: isodate==0.6.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 20)) (0.6.1)
# Requirement already satisfied: jsonschema==4.21.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 21)) (4.21.1)
# Requirement already satisfied: jsonschema-path==0.3.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 22)) (0.3.2)
# Requirement already satisfied: jsonschema-spec==0.2.4 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 23)) (0.2.4)
# Requirement already satisfied: jsonschema-specifications==2023.7.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 24)) (2023.7.1)
# Requirement already satisfied: lazy-object-proxy==1.10.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 25)) (1.10.0)
# Collecting MarkupSafe==2.1.5 (from -r ../../requirements.txt (line 26))
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting more-itertools==10.2.0 (from -r ../../requirements.txt (line 27))
#   Using cached more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: motor==3.3.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 28)) (3.3.2)
# Requirement already satisfied: multidict==6.0.5 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 29)) (6.0.5)
# Collecting numpy==1.26.4 (from -r ../../requirements.txt (line 30))
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: openai==1.12.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 31)) (1.12.0)
# Requirement already satisfied: openapi-core==0.18.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 32)) (0.18.2)
# Requirement already satisfied: openapi-schema-validator==0.6.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 33)) (0.6.2)
# Requirement already satisfied: openapi-spec-validator==0.7.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 34)) (0.7.1)
# Collecting packaging==23.2 (from -r ../../requirements.txt (line 35))
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: parse==1.20.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 36)) (1.20.1)
# Requirement already satisfied: pathable==0.4.3 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 37)) (0.4.3)
# Requirement already satisfied: prance==23.6.21.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 38)) (23.6.21.0)
# Requirement already satisfied: pydantic==2.6.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 39)) (2.6.1)
# Requirement already satisfied: pydantic_core==2.16.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 40)) (2.16.2)
# Requirement already satisfied: pymongo==4.6.1 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 41)) (4.6.1)
# Requirement already satisfied: python-dotenv==1.0.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 42)) (1.0.0)
# Collecting PyYAML==6.0.1 (from -r ../../requirements.txt (line 43))
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: referencing==0.30.2 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 44)) (0.30.2)
# Requirement already satisfied: regex==2023.12.25 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 45)) (2023.12.25)
# Requirement already satisfied: requests==2.31.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 46)) (2.31.0)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 47)) (0.1.4)
# Requirement already satisfied: rpds-py==0.18.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 48)) (0.18.0)
# Requirement already satisfied: ruamel.yaml==0.18.6 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 49)) (0.18.6)
# Requirement already satisfied: ruamel.yaml.clib==0.2.8 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 50)) (0.2.8)
# Requirement already satisfied: semantic-kernel==0.5.1.dev0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 51)) (0.5.1.dev0)
# Requirement already satisfied: six==1.16.0 in /usr/lib/python3/dist-packages (from -r ../../requirements.txt (line 52)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 53)) (1.3.0)
# Collecting tqdm==4.66.2 (from -r ../../requirements.txt (line 55))
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing_extensions==4.9.0 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 56)) (4.9.0)
# Collecting urllib3==2.2.1 (from -r ../../requirements.txt (line 57))
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting Werkzeug==3.0.1 (from -r ../../requirements.txt (line 58))
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: yarl==1.9.4 in /home/pindalu/.local/lib/python3.10/site-packages (from -r ../../requirements.txt (line 59)) (1.9.4)
# Collecting bokeh==3.3.1 (from -r ../../requirements.txt (line 60))
#   Using cached bokeh-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting opentelemetry-api (from -r ../../requirements.txt (line 61))
#   Using cached opentelemetry_api-1.23.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk (from -r ../../requirements.txt (line 62))
#   Using cached opentelemetry_sdk-1.23.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: Jinja2>=2.9 in /home/pindalu/.local/lib/python3.10/site-packages (from bokeh==3.3.1->-r ../../requirements.txt (line 60)) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /home/pindalu/.local/lib/python3.10/site-packages (from bokeh==3.3.1->-r ../../requirements.txt (line 60)) (1.0.7)
# Requirement already satisfied: pandas>=1.2 in /home/pindalu/.local/lib/python3.10/site-packages (from bokeh==3.3.1->-r ../../requirements.txt (line 60)) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/lib/python3/dist-packages (from bokeh==3.3.1->-r ../../requirements.txt (line 60)) (9.0.1)
# Requirement already satisfied: tornado>=5.1 in /home/pindalu/.local/lib/python3.10/site-packages (from bokeh==3.3.1->-r ../../requirements.txt (line 60)) (6.2)
# Collecting xyzservices>=2021.09.1 (from bokeh==3.3.1->-r ../../requirements.txt (line 60))
#   Using cached xyzservices-2023.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api->-r ../../requirements.txt (line 61))
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api->-r ../../requirements.txt (line 61))
#   Using cached importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting opentelemetry-semantic-conventions==0.44b0 (from opentelemetry-sdk->-r ../../requirements.txt (line 62))
#   Using cached opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/pindalu/.local/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api->-r ../../requirements.txt (line 61)) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api->-r ../../requirements.txt (line 61)) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/pindalu/.local/lib/python3.10/site-packages (from pandas>=1.2->bokeh==3.3.1->-r ../../requirements.txt (line 60)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/pindalu/.local/lib/python3.10/site-packages (from pandas>=1.2->bokeh==3.3.1->-r ../../requirements.txt (line 60)) (2024.1)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 4.5 MB/s eta 0:00:004.4 MB/s eta 0:00:01
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached bokeh-3.3.1-py3-none-any.whl (6.8 MB)
# Using cached opentelemetry_api-1.23.0-py3-none-any.whl (58 kB)
# Using cached opentelemetry_sdk-1.23.0-py3-none-any.whl (105 kB)
# Using cached opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl (36 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Using cached xyzservices-2023.10.1-py3-none-any.whl (56 kB)
# Installing collected packages: src, xyzservices, urllib3, tqdm, PyYAML, packaging, opentelemetry-semantic-conventions, numpy, more-itertools, MarkupSafe, importlib-metadata, idna, frozenlist, exceptiongroup, distro, deprecated, charset-normalizer, chardet, certifi, attrs, Werkzeug, opentelemetry-api, anyio, opentelemetry-sdk, bokeh
#   Running setup.py develop for src
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.2
#     Uninstalling MarkupSafe-2.1.2:
#       Successfully uninstalled MarkupSafe-2.1.2
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.3.3
#     Uninstalling frozenlist-1.3.3:
#       Successfully uninstalled frozenlist-1.3.3
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.1.0
#     Uninstalling charset-normalizer-3.1.0:
#       Successfully uninstalled charset-normalizer-3.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.2.3
#     Uninstalling Werkzeug-2.2.3:
#       Successfully uninstalled Werkzeug-2.2.3
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.6.2
#     Uninstalling anyio-3.6.2:
#       Successfully uninstalled anyio-3.6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 4.25.3 which is incompatible.
# tensorboardx 2.6 requires protobuf<4,>=3.8.0, but you have protobuf 4.25.3 which is incompatible.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 PyYAML-6.0.1 Werkzeug-3.0.1 anyio-4.3.0 attrs-23.2.0 bokeh-3.3.1 certifi-2024.2.2 chardet-5.2.0 charset-normalizer-3.3.2 deprecated-1.2.14 distro-1.9.0 exceptiongroup-1.2.0 frozenlist-1.4.1 idna-3.6 importlib-metadata-6.11.0 more-itertools-10.2.0 numpy-1.26.4 opentelemetry-api-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 packaging-23.2 src-0.1.0 tqdm-4.66.2 urllib3-2.2.1 xyzservices-2023.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import numpy as np

from bokeh.io import output_notebook, show, push_notebook
from bokeh.plotting import figure, output_file
from bokeh.models import ColumnDataSource, Select, DateRangeSlider
from bokeh.layouts import layout
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application
#os.environ['BOKEH_ALLOW_WS_ORIGIN'] = "0vl6ks8oikl4409ep62ikv5fod25jc1hj4km96diac88irsujgs7" # for the Bokeh server
#output_notebook()   # enables Bokeh in Jupyter notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       3 import numpy as np
# ----> 5 from bokeh.io import output_notebook, show, push_notebook
#       6 from bokeh.plotting import figure, output_file
#       7 from bokeh.models import ColumnDataSource, Select, DateRangeSlider
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
# create dummy data
time = pd.date_range(start='1/1/2021', periods=100)
night_data = pd.DataFrame({'date': time, 'sensor 1': np.random.rand(100), 'sensor 2': np.random.rand(100), 'sensor 3': np.random.rand(100)})

# Create Bokeh plot for flow rates, derivatives, and histogram
p = figure(title=f"Flow Rates",
            x_axis_type="datetime",
            y_axis_label='Flow rate [l/s]', 
            height=250, #sizing_mode="stretch_width",
            tools="pan,wheel_zoom,box_zoom,reset,zoom_in,zoom_out,yzoom_in,yzoom_out",
            output_backend="webgl")


# === select widget to choose the evaluated sensor; needs to run in a Bokeh server
def server_doc(doc):

    def update_plot(attr, old, new):
        
        # Clear all renderers from the plots
        p.renderers.clear()

        # update title
        p.title.text = f"Flow Rates for sensor '{new}'"
        
        # use ColumnDatasource
        source = ColumnDataSource(data=night_data)

        # Add a line glyph for new sensor
        p.line(source=source, x='date', y=new)                    

        # Update the plot
        # appears not to be necessary, although it was in the original example
        #push_notebook()


    # Select widget to choose the shown sensor
    select = Select(title="Select sensor:", value='y_values', options=list(night_data.columns[1:]))
    select.on_change('value', update_plot)

    # Note: There is also a date range slider
    # date_range_slider = DateRangeSlider(start=start_date, end=end_date, value=(start_date, end_date), step=1)

    # Combine the plots into one layout and display
    l = layout([[select], [p]]) # type: ignore
    l.sizing_mode = "stretch_width" # type: ignore
    doc.add_root(l)

    # Initial plot
    update_plot(None, None, night_data.columns[1])


# Create and show the application (Bokeh server)
handler = FunctionHandler(server_doc)
app = Application(handler)
show(app, notebook_handle=True, notebook_url="http://localhost:8888")
output_file('Yaaay.html')
# Out:
# <script id="p1228">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:43017/autoload.js?bokeh-autoload-element=p1228&bokeh-absolute-url=http://localhost:43017&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
